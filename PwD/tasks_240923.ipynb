# %% [markdown]
# ## Для файла 'laptop_price.csv'
# ### 1. Отобразить распределение веса среди 30% наиболее дорогих и наиболее дешевых НБ
# ### 2. Отобразить распределение количества RAM среди 20% наиболее дорогих и наиболее дешевых НБ
# ### 3. Отобразить распределение по производителям (сколько моделей каждого производителя представлено в выборке)

# %% [markdown]
# ## Для файла 'trades.csv'
# ### 1. Отобразить распределение величины open
# ### 2. Отобразить распределение величины close
# ### 3. Отобразить распределение величины abs(close - open)
# ### 4. Отобразить распределение величины, равной длине промежутка непрерывного роста (когда close >= open)
# ### 5. Отобразить распределение величины, равной длине промежутка непрерывного падения (когда close >= open)
