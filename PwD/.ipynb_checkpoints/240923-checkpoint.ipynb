# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot()
plt.show()

# %%
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot()
plt.show()

# %%
data = [1, 2, 3, 4]
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(data)
plt.show()

# %%
data = [1, 2, 3, 4]
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(data, 'o')
plt.show()

# %%
data = [1, 2, 3, 4]
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(data, '--')
plt.show()

# %%
data = [1, 2, 3, 4]
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(data, 'go')
plt.show()

# %%
data_x = [i for i in range(100)]
data_y = [i*i for i in data_x]
plt.xlabel("x")
plt.ylabel("f(x) = x^2")
plt.plot(data_x, data_y)
plt.show()

# %%
data_x = [i for i in range(100)]
data_y1 = [i*i for i in data_x]
data_y2 = [i**2.1 for i in data_x]
plt.xlabel("x")
plt.ylabel("f(x) = x^2")
plt.plot(data_x, data_y1)
plt.plot(data_x, data_y2)
plt.show()

# %%
data_x = [i for i in range(100)]
data_y1 = [i*i for i in data_x]
data_y2 = [i**2.1 for i in data_x]
plt.xlabel("x")
plt.ylabel("y")
plt.plot(data_x, data_y1, label='f(x) = x ^ 2')
plt.plot(data_x, data_y2, label='f(x) = x ^ 2.1')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
